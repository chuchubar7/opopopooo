# %%
import tensorflow as tf
import numpy as np
from functools import partial

xy = np.loadtxt("data2.csv", delimiter=',', dtype=np.float32)
x_data = xy[0:-178, 0:-1]
y_data = xy[0:-178, [-1]]
x_validation_data = xy[713:, 0:-1]
y_validation_data = xy[713:, [-1]]
n_inputs = 7
n_hidden1 = 300
n_hidden2 = 300
n_hidden3 = 300
n_hidden4 = 300
n_hidden5 = 300
n_hidden6 = 300
n_hidden7 = 300
n_hidden8 = 300
n_hidden9 = 300
n_outputs = 1
learning_rate = 0.01
n_epochs = 2501

with tf.name_scope("prepare"):
    X = tf.placeholder(tf.float32, shape=(None, n_inputs), name = "X")
    Y = tf.placeholder(tf.float32, shape=(None, 1), name = "Y")
    my_dense_layer = partial(
        tf.layers.dense, activation=tf.nn.relu,
        kernel_regularizer=tf.contrib.layers.l2_regularizer(0.001))

with tf.name_scope("dnn"):
    hidden1 = my_dense_layer(X, n_hidden1, name="hidden1", activation = tf.nn.relu)
    hidden2 = my_dense_layer(hidden1, n_hidden2, name="hidden2")
    hidden3 = my_dense_layer(hidden2, n_hidden3, name="hidden3")
    hidden4 = my_dense_layer(hidden3, n_hidden4, name="hidden4")
    hidden5 = my_dense_layer(hidden4, n_hidden5, name="hidden5")
    hidden6 = my_dense_layer(hidden5, n_hidden6, name="hidden6")
    hidden7 = my_dense_layer(hidden6, n_hidden7, name="hidden7")
    hidden8 = my_dense_layer(hidden7, n_hidden8, name="hidden8")
    hidden9 = my_dense_layer(hidden8, n_hidden9, name="hidden9")
    logits = my_dense_layer(hidden9, n_outputs, activation = None, name="outputs")
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels = Y, logits = logits)
    loss = tf.reduce_mean(xentropy, name="loss")

with tf.name_scope("train"):
    optimizer = tf.train.RMSPropOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)
    
with tf.name_scope("eval"):
    predicted = tf.nn.sigmoid(logits)
    correct = tf.equal(tf.round(predicted), Y)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        sess.run(training_op, feed_dict={X: x_data, Y: y_data})
        acc_train = accuracy.eval(feed_dict={X: x_data, Y: y_data})
        acc_val = accuracy.eval(feed_dict={X: x_validation_data, Y: y_validation_data})
        if epoch % 50 == 0:
            print(epoch, " Train accuracy: ", acc_train, " Validation accuracy: ", acc_val)
# Out:
# 0  Train accuracy:  0.6086956  Validation accuracy:  0.64606744
# 50  Train accuracy:  0.6086956  Validation accuracy:  0.64606744
# 100  Train accuracy:  0.6086956  Validation accuracy:  0.64606744
# 150  Train accuracy:  0.41234222  Validation accuracy:  0.41573033
# 200  Train accuracy:  0.799439  Validation accuracy:  0.8258427
# 250  Train accuracy:  0.8078541  Validation accuracy:  0.85393256
# 300  Train accuracy:  0.8064516  Validation accuracy:  0.8651685
# 350  Train accuracy:  0.8274895  Validation accuracy:  0.8764045
# 400  Train accuracy:  0.82468444  Validation accuracy:  0.8651685
# 450  Train accuracy:  0.828892  Validation accuracy:  0.8764045
# 500  Train accuracy:  0.83590466  Validation accuracy:  0.8707865
# 550  Train accuracy:  0.828892  Validation accuracy:  0.8707865
# 600  Train accuracy:  0.83870965  Validation accuracy:  0.8876405
# 650  Train accuracy:  0.78401124  Validation accuracy:  0.8202247
# 700  Train accuracy:  0.83169705  Validation accuracy:  0.8876405
# 750  Train accuracy:  0.8457223  Validation accuracy:  0.8820225
# 800  Train accuracy:  0.8218794  Validation accuracy:  0.8820225
# 850  Train accuracy:  0.8513324  Validation accuracy:  0.8707865
# 900  Train accuracy:  0.8457223  Validation accuracy:  0.8707865
# 950  Train accuracy:  0.8597475  Validation accuracy:  0.8764045
# 1000  Train accuracy:  0.772791  Validation accuracy:  0.78089887
# 1050  Train accuracy:  0.82468444  Validation accuracy:  0.85955054
# 1100  Train accuracy:  0.8345021  Validation accuracy:  0.8483146
# 1150  Train accuracy:  0.84291726  Validation accuracy:  0.8483146
# 1200  Train accuracy:  0.8667602  Validation accuracy:  0.8820225
# 1250  Train accuracy:  0.8541374  Validation accuracy:  0.83146065
# 1300  Train accuracy:  0.87657785  Validation accuracy:  0.8820225
# 1350  Train accuracy:  0.8611501  Validation accuracy:  0.8820225
# 1400  Train accuracy:  0.85554  Validation accuracy:  0.8202247
# 1450  Train accuracy:  0.887798  Validation accuracy:  0.8764045
# 1500  Train accuracy:  0.8611501  Validation accuracy:  0.85393256
# 1550  Train accuracy:  0.89761573  Validation accuracy:  0.8820225
# 1600  Train accuracy:  0.88920057  Validation accuracy:  0.85393256
# 1650  Train accuracy:  0.88920057  Validation accuracy:  0.8820225
# 1700  Train accuracy:  0.8948107  Validation accuracy:  0.8426966
# 1750  Train accuracy:  0.8990182  Validation accuracy:  0.8483146
# 1800  Train accuracy:  0.9018233  Validation accuracy:  0.83707863
# 1850  Train accuracy:  0.87657785  Validation accuracy:  0.8202247
# 1900  Train accuracy:  0.8737728  Validation accuracy:  0.8426966
# 1950  Train accuracy:  0.91023844  Validation accuracy:  0.8258427
# 2000  Train accuracy:  0.9130435  Validation accuracy:  0.8202247
# 2050  Train accuracy:  0.9004208  Validation accuracy:  0.80898875
# 2100  Train accuracy:  0.91023844  Validation accuracy:  0.83707863
# 2150  Train accuracy:  0.91865355  Validation accuracy:  0.8033708
# 2200  Train accuracy:  0.9088359  Validation accuracy:  0.7977528
# 2250  Train accuracy:  0.91725105  Validation accuracy:  0.80898875
# 2300  Train accuracy:  0.8934081  Validation accuracy:  0.7977528
# 2350  Train accuracy:  0.91865355  Validation accuracy:  0.8258427
# 2400  Train accuracy:  0.92987376  Validation accuracy:  0.8202247
# 2450  Train accuracy:  0.91164094  Validation accuracy:  0.8258427
# 2500  Train accuracy:  0.9214586  Validation accuracy:  0.83146065
